# %%
import matplotlib.pyplot as plt
from ising import ising_simulation
from ising_numba import ising_simulation_numba

# %%
for _ in range(5):
    sim = ising_simulation(arr_size= 100, 
                            j = 1, 
                            beta = 1, 
                            force_B = 1, 
                            amount_of_steps = 3, 
                            ups_density = 0.65)
    sim.simulate()
        
sim.simulate.print_stats()
# Out:
# runs: 5
# average (s): 3.315367
# std (s): 0.074416
# min (s): 3.239237
# max (s): 3.450621

# %%
for _ in range(5):
    sim = ising_simulation_numba(arr_size= 100, 
                            j = 1, 
                            beta = 1, 
                            force_B = 1, 
                            amount_of_steps = 3, 
                            ups_density = 0.65)
    sim.simulate()
        
sim.simulate.print_stats()
# Out:
# runs: 5
# average (s): 0.003296
# std (s): 0.000181
# min (s): 0.003122
# max (s): 0.003644
